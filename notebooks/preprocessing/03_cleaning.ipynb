# %%
import re
import os
import shutil

# %%
# change working directory to the /Users/tildeidunsloth/Desktop/DatSci_25/DatSci_25
os.chdir('/Users/tildeidunsloth/Desktop/DatSci_25/DatSci25')
# Set the path to the folder containing the transcript files
folder_path = 'data/txt'

# %%
def clean_text_formatting(text):
    """
    Removes ONLY:
    - Dates like "Tirsdag den 2. april 2024"
    - Page numbers like "(L 123) 5" 
    - Times like "Kl. 14.13"
    - Fix minister titles with hyphens
    """
    # 1. Remove dates (strict patterns)
    date_patterns = [
        r'[A-Za-z]+ den \d+\. [A-Za-z]+ \d{4}\b',  # "Tirsdag den 2. april 2024"
        r'[A-Za-z]+, \d+\. [A-Za-z]+ \d{4}\b',     # "Tirsdag, 2. april 2024"
        r'\d+\. [A-Za-z]+ \d{4}\b',                # "2. april 2024"
    ]

    # 2. Remove page references
    page_patterns = [
        r'\([A-Z] \d+\) \d+\b',  # "(L 123) 5"
        r'\([A-Z] \d+\)\b',      # "(L 123)"
    ]
    
    # 3. Remove times like "Kl. 14.13", "13:06", "kl 13:06", or "kl. 13.06"
    time_patterns = [
        r'\b[Kk]l\.?\s?\d{1,2}[:\.]\d{2}\b',  # Matches "Kl. 14.13", "kl 13:06", "kl. 13.06"
        r'\b\d{1,2}[:\.]\d{2}\b'               # Matches "13:06" or "13.06"
    ]

    # Apply removal patterns
    for pattern in date_patterns + page_patterns + time_patterns:
        text = re.sub(pattern, '', text)

    # 4. Fix hyphenated word splits, but keep "- og"
    text = re.sub(r'(\w+)\s*-\s*(?!og\b)(\w+)', r'\1\2', text)
    
    def normalize_minister_title(match):
        # Split and capitalize the words before "og"
        parts = re.split(r'-\s*,?\s*', match.group(1))
        parts = [p.capitalize() for p in parts if p]

        # Capitalize the word after "og"
        last = match.group(2).capitalize()
        name_and_colon = match.group(3)

        # Recombine all with capitalized "Og"
        title = ' '.join(parts) + ' Og ' + last
        return f"{title}{name_and_colon}"

    text = re.sub(
        r'\b([\wæøåÆØÅ\-]+(?:-\s*,?\s*[\wæøåÆØÅ\-]+)*)\s*-\s*og\s+([\wæøåÆØÅ\-]+)(\s*\([^)]+\):)',
        normalize_minister_title,
        text
    )

    # 6. Clean up formatting artifacts
    text = re.sub(r'\s+', ' ', text)  # Collapse multiple spaces
    text = re.sub(r'\s([,\.])', r'\1', text)  # Fix punctuation spacing
    
    return text.strip()


def clean_all_txt_files(directory_path, output_directory=None):
    """
    Apply clean_text_formatting to all .txt files in a directory.

    Args:
        directory_path (str): Path to directory with .txt files.
        output_directory (str, optional): Where to save cleaned files. If None, overwrites input files.
    """
    if output_directory:
        os.makedirs(output_directory, exist_ok=True)

    for filename in os.listdir(directory_path):
        if filename.endswith('.txt'):
            input_path = os.path.join(directory_path, filename)
            with open(input_path, 'r', encoding='utf-8') as f:
                raw_text = f.read()
            cleaned_text = clean_text_formatting(raw_text)
            
            output_path = (
                os.path.join(output_directory, filename)
                if output_directory else input_path
            )
            with open(output_path, 'w', encoding='utf-8') as f:
                f.write(cleaned_text)

# %%
def clean_single_txt_file(file_path):
    """
    Apply clean_text_formatting to a single .txt file.

    Args:
        file_path (str): Path to the .txt file.
        
    Returns:
        str: Cleaned text from the file.
    """
    with open(file_path, 'r', encoding='utf-8') as f:
        raw_text = f.read()
    
    cleaned_text = clean_text_formatting(raw_text)
    
    return cleaned_text

# %%
# test
test = '''kl 13:05 For desværre finder vi 6 Tirsdag den 2. april 2024 (L 123) rester af pesticider i halvdelen af de danske drikkevandsboringer.. Kl. 13:01 Forhandling Formanden'''
print(clean_text_formatting(test))

test2 = '''hyppig- hed og Miljø- og sundhedsministeren (Lise): men jeg ved ikke med miljø- og sundhedsministeren. Klima-, energi- og Bygningsministeren (Name):'''
print(clean_text_formatting(test2))
# Out:
# For desværre finder vi 6 (L 123) rester af pesticider i halvdelen af de danske drikkevandsboringer.. Forhandling Formanden
# hyppighed og Miljø Og Sundhedsministeren (Lise): men jeg ved ikke med miljø- og sundhedsministeren. Klima Energi Og Bygningsministeren (Name):

# %%
clean_all_txt_files("data/txt", 'data/cleaned')

# %%
# change file structure
def sort_txt_files_by_year(input_folder):
    """
    Sorts .txt files into subfolders based on the 4-digit year in the filename.
    
    Args:
        input_folder (str): Path to the folder containing the .txt files.
    """
    for filename in os.listdir(input_folder):
        if filename.lower().endswith('.txt'):
            try:
                year = filename[0:4]  # take first 4 chars (year)
                if year.isdigit():
                    year_folder = os.path.join(input_folder, year)
                    os.makedirs(year_folder, exist_ok=True)

                    old_path = os.path.join(input_folder, filename)
                    new_path = os.path.join(year_folder, filename)

                    shutil.move(old_path, new_path)
                    print(f"Moved {filename} to {year_folder}")
                else:
                    print(f"⚠️ Year not valid in: {filename}")
            except IndexError:
                print(f"⚠️ Filename too short: {filename}")

    print("\n✅ All files sorted by year!")

# %%
sort_txt_files_by_year('data/cleaned')
# Out:
# Moved 20231_m71.txt to data/cleaned/2023
# Moved 20012_m15.txt to data/cleaned/2001
# Moved 20231_m65.txt to data/cleaned/2023
# Moved 20141_m34.txt to data/cleaned/2014
# Moved 20161_m98.txt to data/cleaned/2016
# Moved 20191_m106.txt to data/cleaned/2019
# Moved 20151_m20.txt to data/cleaned/2015
# Moved 20151_m34.txt to data/cleaned/2015
# Moved 20171_m98.txt to data/cleaned/2017
# Moved 20012_m29.txt to data/cleaned/2001
# Moved 20141_m20.txt to data/cleaned/2014
# Moved 20231_m59.txt to data/cleaned/2023
# Moved 20191_m112.txt to data/cleaned/2019
# Moved 20081_m19.txt to data/cleaned/2008
# Moved 20161_m67.txt to data/cleaned/2016
# Moved 20171_m73.txt to data/cleaned/2017
# Moved 20171_m67.txt to data/cleaned/2017
# Moved 20241_m2.txt to data/cleaned/2024
# Moved 20091_m19.txt to data/cleaned/2009
# Moved 20161_m73.txt to data/cleaned/2016
# Moved 20211_m22.txt to data/cleaned/2021
# Moved 20081_m25.txt to data/cleaned/2008
# Moved 20201_m36.txt to data/cleaned/2020
# Moved 20091_m31.txt to data/cleaned/2009
# Moved 20091_m25.txt to data/cleaned/2009
# Moved 20201_m22.txt to data/cleaned/2020
# Moved 20081_m31.txt to data/cleaned/2008
# Moved 20211_m36.txt to data/cleaned/2021
# Moved 20131_m45.txt to data/cleaned/2013
# Moved 20072_m58.txt to data/cleaned/2007
# Moved 20121_m51.txt to data/cleaned/2012
# Moved 20121_m45.txt to data/cleaned/2012
# Moved 20131_m51.txt to data/cleaned/2013
# Moved 20072_m64.txt to data/cleaned/2007
# Moved 20131_m79.txt to data/cleaned/2013
# Moved 20121_m79.txt to data/cleaned/2012
# Moved 20222_m2.txt to data/cleaned/2022
# Moved 20241_m14.txt to data/cleaned/2024
# Moved 20072_m70.txt to data/cleaned/2007
# Moved 20131_m86.txt to data/cleaned/2013
# Moved 20042_m23.txt to data/cleaned/2004
# Moved 20121_m92.txt to data/cleaned/2012
# Moved 20121_m86.txt to data/cleaned/2012
# Moved 20042_m37.txt to data/cleaned/2004
# Moved 20061_m102.txt to data/cleaned/2006
# Moved 20131_m92.txt to data/cleaned/2013
# Moved 20111_m16.txt to data/cleaned/2011
# Moved 20031_m5.txt to data/cleaned/2003
# Moved 20101_m16.txt to data/cleaned/2010
# Moved 20131_m5.txt to data/cleaned/2013
# Moved 20191_m91.txt to data/cleaned/2019
# Moved 20051_m43.txt to data/cleaned/2005
# Moved 20181_m85.txt to data/cleaned/2018
# Moved 20181_m91.txt to data/cleaned/2018
# Moved 20051_m57.txt to data/cleaned/2005
# Moved 20191_m85.txt to data/cleaned/2019
# Moved 20121_m102.txt to data/cleaned/2012
# Moved 20051_m80.txt to data/cleaned/2005
# Moved 20191_m52.txt to data/cleaned/2019
# Moved 20061_m38.txt to data/cleaned/2006
# Moved 20211_m110.txt to data/cleaned/2021
# Moved 20161_m8.txt to data/cleaned/2016
# Moved 20181_m46.txt to data/cleaned/2018
# Moved 20181_m52.txt to data/cleaned/2018
# Moved 20211_m104.txt to data/cleaned/2021
# Moved 20191_m46.txt to data/cleaned/2019
# Moved 20061_m8.txt to data/cleaned/2006
# Moved 20051_m94.txt to data/cleaned/2005
# Moved 20071_m10.txt to data/cleaned/2007
# Moved 20061_m10.txt to data/cleaned/2006
# Moved 20021_m32.txt to data/cleaned/2002
# Moved 20031_m26.txt to data/cleaned/2003
# Moved 20031_m32.txt to data/cleaned/2003
# Moved 20001_m105.txt to data/cleaned/2000
# Moved 20021_m26.txt to data/cleaned/2002
# Moved 20001_m61.txt to data/cleaned/2000
# Moved 20222_m11.txt to data/cleaned/2022
# Moved 20001_m75.txt to data/cleaned/2000
# Moved 20222_m39.txt to data/cleaned/2022
# Moved 20001_m49.txt to data/cleaned/2000
# Moved 20222_m38.txt to data/cleaned/2022
# Moved 20001_m48.txt to data/cleaned/2000
# Moved 20001_m74.txt to data/cleaned/2000
# Moved 20001_m60.txt to data/cleaned/2000
# Moved 20222_m10.txt to data/cleaned/2022
# Moved 20031_m33.txt to data/cleaned/2003
# Moved 20021_m27.txt to data/cleaned/2002
# Moved 20001_m104.txt to data/cleaned/2000
# Moved 20021_m33.txt to data/cleaned/2002
# Moved 20031_m27.txt to data/cleaned/2003
# Moved 20061_m11.txt to data/cleaned/2006
# Moved 20211_m105.txt to data/cleaned/2021
# Moved 20181_m53.txt to data/cleaned/2018
# Moved 20051_m95.txt to data/cleaned/2005
# Moved 20061_m9.txt to data/cleaned/2006
# Moved 20191_m47.txt to data/cleaned/2019
# Moved 20191_m53.txt to data/cleaned/2019
# Moved 20051_m81.txt to data/cleaned/2005
# Moved 20181_m47.txt to data/cleaned/2018
# Moved 20211_m111.txt to data/cleaned/2021
# Moved 20061_m39.txt to data/cleaned/2006
# Moved 20161_m9.txt to data/cleaned/2016
# Moved 20121_m103.txt to data/cleaned/2012
# Moved 20181_m90.txt to data/cleaned/2018
# Moved 20041_m42.txt to data/cleaned/2004
# Moved 20191_m84.txt to data/cleaned/2019
# Moved 20051_m56.txt to data/cleaned/2005
# Moved 20051_m42.txt to data/cleaned/2005
# Moved 20191_m90.txt to data/cleaned/2019
# Moved 20181_m84.txt to data/cleaned/2018
# Moved 20101_m17.txt to data/cleaned/2010
# Moved 20131_m4.txt to data/cleaned/2013
# Moved 20111_m17.txt to data/cleaned/2011
# Moved 20031_m4.txt to data/cleaned/2003
# Moved 20042_m36.txt to data/cleaned/2004
# Moved 20121_m87.txt to data/cleaned/2012
# Moved 20131_m93.txt to data/cleaned/2013
# Moved 20131_m87.txt to data/cleaned/2013
# Moved 20121_m93.txt to data/cleaned/2012
# Moved 20042_m22.txt to data/cleaned/2004
# Moved 20121_m78.txt to data/cleaned/2012
# Moved 20072_m71.txt to data/cleaned/2007
# Moved 20241_m15.txt to data/cleaned/2024
# Moved 20222_m3.txt to data/cleaned/2022
# Moved 20131_m78.txt to data/cleaned/2013
# Moved 20072_m65.txt to data/cleaned/2007
# Moved 20121_m44.txt to data/cleaned/2012
# Moved 20042_m1.txt to data/cleaned/2004
# Moved 20131_m50.txt to data/cleaned/2013
# Moved 20241_m29.txt to data/cleaned/2024
# Moved 20072_m59.txt to data/cleaned/2007
# Moved 20142_m1.txt to data/cleaned/2014
# Moved 20131_m44.txt to data/cleaned/2013
# Moved 20121_m50.txt to data/cleaned/2012
# Moved 20201_m23.txt to data/cleaned/2020
# Moved 20091_m24.txt to data/cleaned/2009
# Moved 20211_m37.txt to data/cleaned/2021
# Moved 20021_m1.txt to data/cleaned/2002
# Moved 20081_m30.txt to data/cleaned/2008
# Moved 20081_m24.txt to data/cleaned/2008
# Moved 20211_m23.txt to data/cleaned/2021
# Moved 20121_m1.txt to data/cleaned/2012
# Moved 20091_m30.txt to data/cleaned/2009
# Moved 20201_m37.txt to data/cleaned/2020
# Moved 20091_m18.txt to data/cleaned/2009
# Moved 20241_m3.txt to data/cleaned/2024
# Moved 20171_m66.txt to data/cleaned/2017
# Moved 20161_m72.txt to data/cleaned/2016
# Moved 20161_m66.txt to data/cleaned/2016
# Moved 20081_m18.txt to data/cleaned/2008
# Moved 20171_m72.txt to data/cleaned/2017
# Moved 20012_m28.txt to data/cleaned/2001
# Moved 20171_m99.txt to data/cleaned/2017
# Moved 20151_m35.txt to data/cleaned/2015
# Moved 20191_m113.txt to data/cleaned/2019
# Moved 20141_m21.txt to data/cleaned/2014
# Moved 20231_m58.txt to data/cleaned/2023
# Moved 20161_m99.txt to data/cleaned/2016
# Moved 20191_m107.txt to data/cleaned/2019
# Moved 20141_m35.txt to data/cleaned/2014
# Moved 20151_m21.txt to data/cleaned/2015
# Moved 20012_m14.txt to data/cleaned/2001
# Moved 20231_m64.txt to data/cleaned/2023
# Moved 20231_m70.txt to data/cleaned/2023
# Moved 20231_m66.txt to data/cleaned/2023
# Moved 20012_m16.txt to data/cleaned/2001
# Moved 20231_m72.txt to data/cleaned/2023
# Moved 20191_m139.txt to data/cleaned/2019
# Moved 20141_m23.txt to data/cleaned/2014
# Moved 20191_m111.txt to data/cleaned/2019
# Moved 20151_m37.txt to data/cleaned/2015
# Moved 20151_m23.txt to data/cleaned/2015
# Moved 20141_m37.txt to data/cleaned/2014
# Moved 20191_m105.txt to data/cleaned/2019
# Moved 20161_m70.txt to data/cleaned/2016
# Moved 20171_m64.txt to data/cleaned/2017
# Moved 20241_m1.txt to data/cleaned/2024
# Moved 20171_m70.txt to data/cleaned/2017
# Moved 20161_m64.txt to data/cleaned/2016
# Moved 20081_m32.txt to data/cleaned/2008
# Moved 20021_m3.txt to data/cleaned/2002
# Moved 20211_m35.txt to data/cleaned/2021
# Moved 20231_m99.txt to data/cleaned/2023
# Moved 20091_m26.txt to data/cleaned/2009
# Moved 20171_m58.txt to data/cleaned/2017
# Moved 20201_m21.txt to data/cleaned/2020
# Moved 20201_m35.txt to data/cleaned/2020
# Moved 20091_m32.txt to data/cleaned/2009
# Moved 20121_m3.txt to data/cleaned/2012
# Moved 20161_m58.txt to data/cleaned/2016
# Moved 20211_m21.txt to data/cleaned/2021
# Moved 20081_m26.txt to data/cleaned/2008
# Moved 20131_m52.txt to data/cleaned/2013
# Moved 20042_m3.txt to data/cleaned/2004
# Moved 20121_m46.txt to data/cleaned/2012
# Moved 20121_m52.txt to data/cleaned/2012
# Moved 20131_m46.txt to data/cleaned/2013
# Moved 20142_m3.txt to data/cleaned/2014
# Moved 20241_m17.txt to data/cleaned/2024
# Moved 20222_m1.txt to data/cleaned/2022
# Moved 20072_m73.txt to data/cleaned/2007
# Moved 20072_m67.txt to data/cleaned/2007
# Moved 20131_m91.txt to data/cleaned/2013
# Moved 20121_m85.txt to data/cleaned/2012
# Moved 20101_m29.txt to data/cleaned/2010
# Moved 20061_m101.txt to data/cleaned/2006
# Moved 20042_m34.txt to data/cleaned/2004
# Moved 20042_m20.txt to data/cleaned/2004
# Moved 20121_m91.txt to data/cleaned/2012
# Moved 20131_m85.txt to data/cleaned/2013
# Moved 20111_m29.txt to data/cleaned/2011
# Moved 20131_m6.txt to data/cleaned/2013
# Moved 20101_m15.txt to data/cleaned/2010
# Moved 20031_m6.txt to data/cleaned/2003
# Moved 20111_m15.txt to data/cleaned/2011
# Moved 20051_m54.txt to data/cleaned/2005
# Moved 20191_m86.txt to data/cleaned/2019
# Moved 20041_m40.txt to data/cleaned/2004
# Moved 20181_m92.txt to data/cleaned/2018
# Moved 20181_m86.txt to data/cleaned/2018
# Moved 20191_m92.txt to data/cleaned/2019
# Moved 20051_m40.txt to data/cleaned/2005
# Moved 20051_m68.txt to data/cleaned/2005
# Moved 20121_m115.txt to data/cleaned/2012
# Moved 20121_m101.txt to data/cleaned/2012
# Moved 20191_m45.txt to data/cleaned/2019
# Moved 20051_m97.txt to data/cleaned/2005
# Moved 20181_m51.txt to data/cleaned/2018
# Moved 20211_m107.txt to data/cleaned/2021
# Moved 20211_m113.txt to data/cleaned/2021
# Moved 20181_m45.txt to data/cleaned/2018
# Moved 20051_m83.txt to data/cleaned/2005
# Moved 20191_m51.txt to data/cleaned/2019
# Moved 20191_m79.txt to data/cleaned/2019
# Moved 20061_m13.txt to data/cleaned/2006
# Moved 20201_m9.txt to data/cleaned/2020
# Moved 20181_m79.txt to data/cleaned/2018
# Moved 20021_m19.txt to data/cleaned/2002
# Moved 20031_m19.txt to data/cleaned/2003
# Moved 20001_m89.txt to data/cleaned/2000
# Moved 20021_m25.txt to data/cleaned/2002
# Moved 20031_m31.txt to data/cleaned/2003
# Moved 20031_m25.txt to data/cleaned/2003
# Moved 20021_m31.txt to data/cleaned/2002
# Moved 20001_m76.txt to data/cleaned/2000
# Moved 20222_m12.txt to data/cleaned/2022
# Moved 20001_m62.txt to data/cleaned/2000
# Moved 20222_m13.txt to data/cleaned/2022
# Moved 20001_m63.txt to data/cleaned/2000
# Moved 20001_m77.txt to data/cleaned/2000
# Moved 20031_m24.txt to data/cleaned/2003
# Moved 20021_m30.txt to data/cleaned/2002
# Moved 20021_m24.txt to data/cleaned/2002
# Moved 20001_m88.txt to data/cleaned/2000
# Moved 20031_m30.txt to data/cleaned/2003
# Moved 20031_m18.txt to data/cleaned/2003
# Moved 20021_m18.txt to data/cleaned/2002
# Moved 20181_m78.txt to data/cleaned/2018
# Moved 20191_m78.txt to data/cleaned/2019
# Moved 20201_m8.txt to data/cleaned/2020
# Moved 20061_m12.txt to data/cleaned/2006
# Moved 20181_m44.txt to data/cleaned/2018
# Moved 20211_m112.txt to data/cleaned/2021
# Moved 20191_m50.txt to data/cleaned/2019
# Moved 20051_m82.txt to data/cleaned/2005
# Moved 20051_m96.txt to data/cleaned/2005
# Moved 20191_m44.txt to data/cleaned/2019
# Moved 20211_m106.txt to data/cleaned/2021
# Moved 20181_m50.txt to data/cleaned/2018
# Moved 20121_m100.txt to data/cleaned/2012
# Moved 20051_m69.txt to data/cleaned/2005
# Moved 20121_m114.txt to data/cleaned/2012
# Moved 20181_m87.txt to data/cleaned/2018
# Moved 20051_m41.txt to data/cleaned/2005
# Moved 20191_m93.txt to data/cleaned/2019
# Moved 20191_m87.txt to data/cleaned/2019
# Moved 20051_m55.txt to data/cleaned/2005
# Moved 20181_m93.txt to data/cleaned/2018
# Moved 20041_m41.txt to data/cleaned/2004
# Moved 20031_m7.txt to data/cleaned/2003
# Moved 20111_m14.txt to data/cleaned/2011
# Moved 20131_m7.txt to data/cleaned/2013
# Moved 20101_m14.txt to data/cleaned/2010
# Moved 20121_m90.txt to data/cleaned/2012
# Moved 20042_m21.txt to data/cleaned/2004
# Moved 20111_m28.txt to data/cleaned/2011
# Moved 20131_m84.txt to data/cleaned/2013
# Moved 20131_m90.txt to data/cleaned/2013
# Moved 20042_m35.txt to data/cleaned/2004
# Moved 20061_m100.txt to data/cleaned/2006
# Moved 20101_m28.txt to data/cleaned/2010
# Moved 20121_m84.txt to data/cleaned/2012
# Moved 20072_m66.txt to data/cleaned/2007
# Moved 20072_m72.txt to data/cleaned/2007
# Moved 20241_m16.txt to data/cleaned/2024
# Moved 20121_m53.txt to data/cleaned/2012
# Moved 20142_m2.txt to data/cleaned/2014
# Moved 20131_m47.txt to data/cleaned/2013
# Moved 20131_m53.txt to data/cleaned/2013
# Moved 20121_m47.txt to data/cleaned/2012
# Moved 20042_m2.txt to data/cleaned/2004
# Moved 20091_m33.txt to data/cleaned/2009
# Moved 20121_m2.txt to data/cleaned/2012
# Moved 20201_m34.txt to data/cleaned/2020
# Moved 20081_m27.txt to data/cleaned/2008
# Moved 20161_m59.txt to data/cleaned/2016
# Moved 20211_m20.txt to data/cleaned/2021
# Moved 20231_m98.txt to data/cleaned/2023
# Moved 20211_m34.txt to data/cleaned/2021
# Moved 20081_m33.txt to data/cleaned/2008
# Moved 20021_m2.txt to data/cleaned/2002
# Moved 20171_m59.txt to data/cleaned/2017
# Moved 20201_m20.txt to data/cleaned/2020
# Moved 20091_m27.txt to data/cleaned/2009
# Moved 20171_m71.txt to data/cleaned/2017
# Moved 20161_m65.txt to data/cleaned/2016
# Moved 20161_m71.txt to data/cleaned/2016
# Moved 20171_m65.txt to data/cleaned/2017
# Moved 20151_m22.txt to data/cleaned/2015
# Moved 20191_m104.txt to data/cleaned/2019
# Moved 20141_m36.txt to data/cleaned/2014
# Moved 20191_m110.txt to data/cleaned/2019
# Moved 20141_m22.txt to data/cleaned/2014
# Moved 20151_m36.txt to data/cleaned/2015
# Moved 20191_m138.txt to data/cleaned/2019
# Moved 20231_m73.txt to data/cleaned/2023
# Moved 20231_m67.txt to data/cleaned/2023
# Moved 20012_m17.txt to data/cleaned/2001
# Moved 20151_m32.txt to data/cleaned/2015
# Moved 20141_m26.txt to data/cleaned/2014
# Moved 20191_m114.txt to data/cleaned/2019
# Moved 20182_m8.txt to data/cleaned/2018
# Moved 20141_m32.txt to data/cleaned/2014
# Moved 20191_m100.txt to data/cleaned/2019
# Moved 20151_m26.txt to data/cleaned/2015
# Moved 20012_m13.txt to data/cleaned/2001
# Moved 20231_m63.txt to data/cleaned/2023
# Moved 20191_m128.txt to data/cleaned/2019
# Moved 20231_m77.txt to data/cleaned/2023
# Moved 20091_m23.txt to data/cleaned/2009
# Moved 20201_m24.txt to data/cleaned/2020
# Moved 20021_m6.txt to data/cleaned/2002
# Moved 20081_m37.txt to data/cleaned/2008
# Moved 20161_m49.txt to data/cleaned/2016
# Moved 20211_m30.txt to data/cleaned/2021
# Moved 20211_m24.txt to data/cleaned/2021
# Moved 20231_m88.txt to data/cleaned/2023
# Moved 20081_m23.txt to data/cleaned/2008
# Moved 20171_m49.txt to data/cleaned/2017
# Moved 20201_m30.txt to data/cleaned/2020
# Moved 20121_m6.txt to data/cleaned/2012
# Moved 20091_m37.txt to data/cleaned/2009
# Moved 20201_m18.txt to data/cleaned/2020
# Moved 20171_m61.txt to data/cleaned/2017
# Moved 20241_m4.txt to data/cleaned/2024
# Moved 20161_m75.txt to data/cleaned/2016
# Moved 20211_m18.txt to data/cleaned/2021
# Moved 20161_m61.txt to data/cleaned/2016
# Moved 20171_m75.txt to data/cleaned/2017
# Moved 20241_m12.txt to data/cleaned/2024
# Moved 20222_m4.txt to data/cleaned/2022
# Moved 20072_m76.txt to data/cleaned/2007
# Moved 20072_m62.txt to data/cleaned/2007
# Moved 20042_m6.txt to data/cleaned/2004
# Moved 20121_m43.txt to data/cleaned/2012
# Moved 20131_m57.txt to data/cleaned/2013
# Moved 20131_m43.txt to data/cleaned/2013
# Moved 20142_m6.txt to data/cleaned/2014
# Moved 20121_m57.txt to data/cleaned/2012
# Moved 20101_m10.txt to data/cleaned/2010
# Moved 20131_m3.txt to data/cleaned/2013
# Moved 20111_m10.txt to data/cleaned/2011
# Moved 20031_m3.txt to data/cleaned/2003
# Moved 20042_m19.txt to data/cleaned/2004
# Moved 20121_m80.txt to data/cleaned/2012
# Moved 20042_m31.txt to data/cleaned/2004
# Moved 20131_m94.txt to data/cleaned/2013
# Moved 20111_m38.txt to data/cleaned/2011
# Moved 20131_m80.txt to data/cleaned/2013
# Moved 20042_m25.txt to data/cleaned/2004
# Moved 20121_m94.txt to data/cleaned/2012
# Moved 20101_m38.txt to data/cleaned/2010
# Moved 20121_m110.txt to data/cleaned/2012
# Moved 20051_m79.txt to data/cleaned/2005
# Moved 20121_m104.txt to data/cleaned/2012
# Moved 20051_m51.txt to data/cleaned/2005
# Moved 20191_m83.txt to data/cleaned/2019
# Moved 20191_m97.txt to data/cleaned/2019
# Moved 20051_m45.txt to data/cleaned/2005
# Moved 20181_m83.txt to data/cleaned/2018
# Moved 20061_m16.txt to data/cleaned/2006
# Moved 20181_m68.txt to data/cleaned/2018
# Moved 20191_m68.txt to data/cleaned/2019
# Moved 20181_m54.txt to data/cleaned/2018
# Moved 20211_m102.txt to data/cleaned/2021
# Moved 20191_m40.txt to data/cleaned/2019
# Moved 20051_m92.txt to data/cleaned/2005
# Moved 20051_m86.txt to data/cleaned/2005
# Moved 20191_m54.txt to data/cleaned/2019
# Moved 20211_m116.txt to data/cleaned/2021
# Moved 20181_m40.txt to data/cleaned/2018
# Moved 20031_m34.txt to data/cleaned/2003
# Moved 20001_m103.txt to data/cleaned/2000
# Moved 20021_m20.txt to data/cleaned/2002
# Moved 20001_m98.txt to data/cleaned/2000
# Moved 20021_m34.txt to data/cleaned/2002
# Moved 20031_m20.txt to data/cleaned/2003
# Moved 20211_m9.txt to data/cleaned/2021
# Moved 20001_m73.txt to data/cleaned/2000
# Moved 20001_m67.txt to data/cleaned/2000
# Moved 20222_m17.txt to data/cleaned/2022
# Moved 20001_m66.txt to data/cleaned/2000
# Moved 20222_m16.txt to data/cleaned/2022
# Moved 20001_m72.txt to data/cleaned/2000
# Moved 20211_m8.txt to data/cleaned/2021
# Moved 20021_m35.txt to data/cleaned/2002
# Moved 20001_m99.txt to data/cleaned/2000
# Moved 20031_m21.txt to data/cleaned/2003
# Moved 20031_m35.txt to data/cleaned/2003
# Moved 20021_m21.txt to data/cleaned/2002
# Moved 20001_m102.txt to data/cleaned/2000
# Moved 20191_m55.txt to data/cleaned/2019
# Moved 20051_m87.txt to data/cleaned/2005
# Moved 20181_m41.txt to data/cleaned/2018
# Moved 20211_m117.txt to data/cleaned/2021
# Moved 20211_m103.txt to data/cleaned/2021
# Moved 20181_m55.txt to data/cleaned/2018
# Moved 20051_m93.txt to data/cleaned/2005
# Moved 20191_m41.txt to data/cleaned/2019
# Moved 20191_m69.txt to data/cleaned/2019
# Moved 20181_m69.txt to data/cleaned/2018
# Moved 20061_m17.txt to data/cleaned/2006
# Moved 20051_m44.txt to data/cleaned/2005
# Moved 20191_m96.txt to data/cleaned/2019
# Moved 20181_m82.txt to data/cleaned/2018
# Moved 20191_m82.txt to data/cleaned/2019
# Moved 20051_m50.txt to data/cleaned/2005
# Moved 20051_m78.txt to data/cleaned/2005
# Moved 20121_m105.txt to data/cleaned/2012
# Moved 20121_m111.txt to data/cleaned/2012
# Moved 20131_m81.txt to data/cleaned/2013
# Moved 20101_m39.txt to data/cleaned/2010
# Moved 20121_m95.txt to data/cleaned/2012
# Moved 20042_m24.txt to data/cleaned/2004
# Moved 20042_m30.txt to data/cleaned/2004
# Moved 20121_m81.txt to data/cleaned/2012
# Moved 20111_m39.txt to data/cleaned/2011
# Moved 20131_m95.txt to data/cleaned/2013
# Moved 20111_m11.txt to data/cleaned/2011
# Moved 20042_m18.txt to data/cleaned/2004
# Moved 20031_m2.txt to data/cleaned/2003
# Moved 20101_m11.txt to data/cleaned/2010
# Moved 20131_m2.txt to data/cleaned/2013
# Moved 20131_m42.txt to data/cleaned/2013
# Moved 20121_m56.txt to data/cleaned/2012
# Moved 20121_m42.txt to data/cleaned/2012
# Moved 20042_m7.txt to data/cleaned/2004
# Moved 20131_m56.txt to data/cleaned/2013
# Moved 20072_m63.txt to data/cleaned/2007
# Moved 20072_m77.txt to data/cleaned/2007
# Moved 20222_m5.txt to data/cleaned/2022
# Moved 20241_m13.txt to data/cleaned/2024
# Moved 20211_m19.txt to data/cleaned/2021
# Moved 20161_m60.txt to data/cleaned/2016
# Moved 20171_m74.txt to data/cleaned/2017
# Moved 20241_m5.txt to data/cleaned/2024
# Moved 20201_m19.txt to data/cleaned/2020
# Moved 20171_m60.txt to data/cleaned/2017
# Moved 20161_m74.txt to data/cleaned/2016
# Moved 20081_m22.txt to data/cleaned/2008
# Moved 20231_m89.txt to data/cleaned/2023
# Moved 20211_m25.txt to data/cleaned/2021
# Moved 20121_m7.txt to data/cleaned/2012
# Moved 20091_m36.txt to data/cleaned/2009
# Moved 20171_m48.txt to data/cleaned/2017
# Moved 20201_m31.txt to data/cleaned/2020
# Moved 20201_m25.txt to data/cleaned/2020
# Moved 20091_m22.txt to data/cleaned/2009
# Moved 20161_m48.txt to data/cleaned/2016
# Moved 20211_m31.txt to data/cleaned/2021
# Moved 20021_m7.txt to data/cleaned/2002
# Moved 20081_m36.txt to data/cleaned/2008
# Moved 20231_m76.txt to data/cleaned/2023
# Moved 20012_m12.txt to data/cleaned/2001
# Moved 20191_m129.txt to data/cleaned/2019
# Moved 20231_m62.txt to data/cleaned/2023
# Moved 20191_m101.txt to data/cleaned/2019
# Moved 20141_m33.txt to data/cleaned/2014
# Moved 20151_m27.txt to data/cleaned/2015
# Moved 20151_m33.txt to data/cleaned/2015
# Moved 20191_m115.txt to data/cleaned/2019
# Moved 20141_m27.txt to data/cleaned/2014
# Moved 20012_m38.txt to data/cleaned/2001
# Moved 20151_m25.txt to data/cleaned/2015
# Moved 20171_m89.txt to data/cleaned/2017
# Moved 20141_m31.txt to data/cleaned/2014
# Moved 20231_m48.txt to data/cleaned/2023
# Moved 20191_m103.txt to data/cleaned/2019
# Moved 20141_m25.txt to data/cleaned/2014
# Moved 20161_m89.txt to data/cleaned/2016
# Moved 20191_m117.txt to data/cleaned/2019
# Moved 20151_m31.txt to data/cleaned/2015
# Moved 20151_m19.txt to data/cleaned/2015
# Moved 20231_m74.txt to data/cleaned/2023
# Moved 20231_m60.txt to data/cleaned/2023
# Moved 20141_m19.txt to data/cleaned/2014
# Moved 20012_m10.txt to data/cleaned/2001
# Moved 20201_m33.txt to data/cleaned/2020
# Moved 20091_m34.txt to data/cleaned/2009
# Moved 20121_m5.txt to data/cleaned/2012
# Moved 20211_m27.txt to data/cleaned/2021
# Moved 20081_m20.txt to data/cleaned/2008
# Moved 20081_m34.txt to data/cleaned/2008
# Moved 20021_m5.txt to data/cleaned/2002
# Moved 20211_m33.txt to data/cleaned/2021
# Moved 20091_m20.txt to data/cleaned/2009
# Moved 20201_m27.txt to data/cleaned/2020
# Moved 20171_m76.txt to data/cleaned/2017
# Moved 20161_m62.txt to data/cleaned/2016
# Moved 20161_m76.txt to data/cleaned/2016
# Moved 20171_m62.txt to data/cleaned/2017
# Moved 20241_m7.txt to data/cleaned/2024
# Moved 20121_m68.txt to data/cleaned/2012
# Moved 20072_m61.txt to data/cleaned/2007
# Moved 20222_m7.txt to data/cleaned/2022
# Moved 20241_m11.txt to data/cleaned/2024
# Moved 20131_m68.txt to data/cleaned/2013
# Moved 20072_m75.txt to data/cleaned/2007
# Moved 20121_m54.txt to data/cleaned/2012
# Moved 20131_m40.txt to data/cleaned/2013
# Moved 20241_m39.txt to data/cleaned/2024
# Moved 20142_m5.txt to data/cleaned/2014
# Moved 20072_m49.txt to data/cleaned/2007
# Moved 20131_m54.txt to data/cleaned/2013
# Moved 20042_m5.txt to data/cleaned/2004
# Moved 20121_m40.txt to data/cleaned/2012
# Moved 20171_m108.txt to data/cleaned/2017
# Moved 20111_m13.txt to data/cleaned/2011
# Moved 20101_m13.txt to data/cleaned/2010
# Moved 20042_m26.txt to data/cleaned/2004
# Moved 20121_m97.txt to data/cleaned/2012
# Moved 20131_m83.txt to data/cleaned/2013
# Moved 20131_m97.txt to data/cleaned/2013
# Moved 20121_m83.txt to data/cleaned/2012
# Moved 20042_m32.txt to data/cleaned/2004
# Moved 20121_m107.txt to data/cleaned/2012
# Moved 20012_m8.txt to data/cleaned/2001
# Moved 20121_m113.txt to data/cleaned/2012
# Moved 20181_m80.txt to data/cleaned/2018
# Moved 20191_m94.txt to data/cleaned/2019
# Moved 20051_m46.txt to data/cleaned/2005
# Moved 20051_m52.txt to data/cleaned/2005
# Moved 20191_m80.txt to data/cleaned/2019
# Moved 20211_m129.txt to data/cleaned/2021
# Moved 20061_m15.txt to data/cleaned/2006
# Moved 20211_m115.txt to data/cleaned/2021
# Moved 20181_m43.txt to data/cleaned/2018
# Moved 20051_m85.txt to data/cleaned/2005
# Moved 20191_m57.txt to data/cleaned/2019
# Moved 20191_m43.txt to data/cleaned/2019
# Moved 20051_m91.txt to data/cleaned/2005
# Moved 20181_m57.txt to data/cleaned/2018
# Moved 20211_m101.txt to data/cleaned/2021
# Moved 20061_m29.txt to data/cleaned/2006
# Moved 20031_m23.txt to data/cleaned/2003
# Moved 20021_m37.txt to data/cleaned/2002
# Moved 20001_m100.txt to data/cleaned/2000
# Moved 20021_m23.txt to data/cleaned/2002
# Moved 20031_m37.txt to data/cleaned/2003
# Moved 20222_m28.txt to data/cleaned/2022
# Moved 20001_m58.txt to data/cleaned/2000
# Moved 20222_m14.txt to data/cleaned/2022
# Moved 20071_m8.txt to data/cleaned/2007
# Moved 20001_m64.txt to data/cleaned/2000
# Moved 20171_m8.txt to data/cleaned/2017
# Moved 20001_m70.txt to data/cleaned/2000
# Moved 20001_m71.txt to data/cleaned/2000
# Moved 20171_m9.txt to data/cleaned/2017
# Moved 20071_m9.txt to data/cleaned/2007
# Moved 20222_m15.txt to data/cleaned/2022
# Moved 20001_m65.txt to data/cleaned/2000
# Moved 20222_m29.txt to data/cleaned/2022
# Moved 20001_m59.txt to data/cleaned/2000
# Moved 20021_m22.txt to data/cleaned/2002
# Moved 20001_m101.txt to data/cleaned/2000
# Moved 20031_m36.txt to data/cleaned/2003
# Moved 20031_m22.txt to data/cleaned/2003
# Moved 20021_m36.txt to data/cleaned/2002
# Moved 20051_m90.txt to data/cleaned/2005
# Moved 20191_m42.txt to data/cleaned/2019
# Moved 20061_m28.txt to data/cleaned/2006
# Moved 20211_m100.txt to data/cleaned/2021
# Moved 20181_m56.txt to data/cleaned/2018
# Moved 20181_m42.txt to data/cleaned/2018
# Moved 20211_m114.txt to data/cleaned/2021
# Moved 20191_m56.txt to data/cleaned/2019
# Moved 20051_m84.txt to data/cleaned/2005
# Moved 20061_m14.txt to data/cleaned/2006
# Moved 20211_m128.txt to data/cleaned/2021
# Moved 20191_m81.txt to data/cleaned/2019
# Moved 20051_m53.txt to data/cleaned/2005
# Moved 20181_m81.txt to data/cleaned/2018
# Moved 20051_m47.txt to data/cleaned/2005
# Moved 20191_m95.txt to data/cleaned/2019
# Moved 20121_m112.txt to data/cleaned/2012
# Moved 20121_m106.txt to data/cleaned/2012
# Moved 20012_m9.txt to data/cleaned/2001
# Moved 20131_m96.txt to data/cleaned/2013
# Moved 20042_m33.txt to data/cleaned/2004
# Moved 20121_m82.txt to data/cleaned/2012
# Moved 20121_m96.txt to data/cleaned/2012
# Moved 20042_m27.txt to data/cleaned/2004
# Moved 20131_m82.txt to data/cleaned/2013
# Moved 20131_m1.txt to data/cleaned/2013
# Moved 20101_m12.txt to data/cleaned/2010
# Moved 20031_m1.txt to data/cleaned/2003
# Moved 20111_m12.txt to data/cleaned/2011
# Moved 20131_m55.txt to data/cleaned/2013
# Moved 20072_m48.txt to data/cleaned/2007
# Moved 20121_m41.txt to data/cleaned/2012
# Moved 20042_m4.txt to data/cleaned/2004
# Moved 20121_m55.txt to data/cleaned/2012
# Moved 20142_m4.txt to data/cleaned/2014
# Moved 20131_m41.txt to data/cleaned/2013
# Moved 20241_m38.txt to data/cleaned/2024
# Moved 20072_m74.txt to data/cleaned/2007
# Moved 20241_m10.txt to data/cleaned/2024
# Moved 20131_m69.txt to data/cleaned/2013
# Moved 20222_m6.txt to data/cleaned/2022
# Moved 20121_m69.txt to data/cleaned/2012
# Moved 20072_m60.txt to data/cleaned/2007
# Moved 20161_m77.txt to data/cleaned/2016
# Moved 20241_m6.txt to data/cleaned/2024
# Moved 20171_m63.txt to data/cleaned/2017
# Moved 20171_m77.txt to data/cleaned/2017
# Moved 20161_m63.txt to data/cleaned/2016
# Moved 20211_m32.txt to data/cleaned/2021
# Moved 20081_m35.txt to data/cleaned/2008
# Moved 20021_m4.txt to data/cleaned/2002
# Moved 20201_m26.txt to data/cleaned/2020
# Moved 20091_m21.txt to data/cleaned/2009
# Moved 20091_m35.txt to data/cleaned/2009
# Moved 20121_m4.txt to data/cleaned/2012
# Moved 20201_m32.txt to data/cleaned/2020
# Moved 20081_m21.txt to data/cleaned/2008
# Moved 20211_m26.txt to data/cleaned/2021
# Moved 20231_m61.txt to data/cleaned/2023
# Moved 20141_m18.txt to data/cleaned/2014
# Moved 20012_m11.txt to data/cleaned/2001
# Moved 20151_m18.txt to data/cleaned/2015
# Moved 20231_m75.txt to data/cleaned/2023
# Moved 20161_m88.txt to data/cleaned/2016
# Moved 20191_m116.txt to data/cleaned/2019
# Moved 20141_m24.txt to data/cleaned/2014
# Moved 20151_m30.txt to data/cleaned/2015
# Moved 20171_m88.txt to data/cleaned/2017
# Moved 20151_m24.txt to data/cleaned/2015
# Moved 20012_m39.txt to data/cleaned/2001
# Moved 20191_m102.txt to data/cleaned/2019
# Moved 20141_m30.txt to data/cleaned/2014
# Moved 20231_m49.txt to data/cleaned/2023
# Moved 20012_m62.txt to data/cleaned/2001
# Moved 20131_m102.txt to data/cleaned/2013
# Moved 20231_m12.txt to data/cleaned/2023
# Moved 20012_m76.txt to data/cleaned/2001
# Moved 20151_m43.txt to data/cleaned/2015
# Moved 20191_m5.txt to data/cleaned/2019
# Moved 20201_m96.txt to data/cleaned/2020
# Moved 20091_m91.txt to data/cleaned/2009
# Moved 20141_m57.txt to data/cleaned/2014
# Moved 20211_m82.txt to data/cleaned/2021
# Moved 20081_m85.txt to data/cleaned/2008
# Moved 20081_m91.txt to data/cleaned/2008
# Moved 20141_m43.txt to data/cleaned/2014
# Moved 20091_m5.txt to data/cleaned/2009
# Moved 20211_m96.txt to data/cleaned/2021
# Moved 20091_m85.txt to data/cleaned/2009
# Moved 20151_m57.txt to data/cleaned/2015
# Moved 20201_m82.txt to data/cleaned/2020
# Moved 20201_m69.txt to data/cleaned/2020
# Moved 20171_m10.txt to data/cleaned/2017
# Moved 20211_m69.txt to data/cleaned/2021
# Moved 20161_m10.txt to data/cleaned/2016
# Moved 20201_m138.txt to data/cleaned/2020
# Moved 20091_m52.txt to data/cleaned/2009
# Moved 20201_m55.txt to data/cleaned/2020
# Moved 20151_m80.txt to data/cleaned/2015
# Moved 20081_m46.txt to data/cleaned/2008
# Moved 20201_m110.txt to data/cleaned/2020
# Moved 20161_m38.txt to data/cleaned/2016
# Moved 20211_m41.txt to data/cleaned/2021
# Moved 20141_m94.txt to data/cleaned/2014
# Moved 20211_m55.txt to data/cleaned/2021
# Moved 20201_m104.txt to data/cleaned/2020
# Moved 20141_m80.txt to data/cleaned/2014
# Moved 20081_m52.txt to data/cleaned/2008
# Moved 20171_m38.txt to data/cleaned/2017
# Moved 20201_m41.txt to data/cleaned/2020
# Moved 20151_m94.txt to data/cleaned/2015
# Moved 20091_m46.txt to data/cleaned/2009
# Moved 20121_m32.txt to data/cleaned/2012
# Moved 20131_m26.txt to data/cleaned/2013
# Moved 20131_m32.txt to data/cleaned/2013
# Moved 20121_m26.txt to data/cleaned/2012
# Moved 20231_m9.txt to data/cleaned/2023
# Moved 20241_m63.txt to data/cleaned/2024
# Moved 20072_m13.txt to data/cleaned/2007
# Moved 20241_m77.txt to data/cleaned/2024
# Moved 20042_m40.txt to data/cleaned/2004
# Moved 20111_m49.txt to data/cleaned/2011
# Moved 20042_m54.txt to data/cleaned/2004
# Moved 20101_m49.txt to data/cleaned/2010
# Moved 20101_m61.txt to data/cleaned/2010
# Moved 20111_m75.txt to data/cleaned/2011
# Moved 20111_m61.txt to data/cleaned/2011
# Moved 20101_m75.txt to data/cleaned/2010
# Moved 20041_m34.txt to data/cleaned/2004
# Moved 20061_m98.txt to data/cleaned/2006
# Moved 20051_m20.txt to data/cleaned/2005
# Moved 20051_m34.txt to data/cleaned/2005
# Moved 20041_m20.txt to data/cleaned/2004
# Moved 20101_m6.txt to data/cleaned/2010
# Moved 20091_m109.txt to data/cleaned/2009
# Moved 20001_m6.txt to data/cleaned/2000
# Moved 20181_m25.txt to data/cleaned/2018
# Moved 20072_m3.txt to data/cleaned/2007
# Moved 20191_m31.txt to data/cleaned/2019
# Moved 20191_m25.txt to data/cleaned/2019
# Moved 20181_m31.txt to data/cleaned/2018
# Moved 20061_m67.txt to data/cleaned/2006
# Moved 20151_m105.txt to data/cleaned/2015
# Moved 20181_m19.txt to data/cleaned/2018
# Moved 20191_m19.txt to data/cleaned/2019
# Moved 20061_m73.txt to data/cleaned/2006
# Moved 20151_m111.txt to data/cleaned/2015
# Moved 20031_m79.txt to data/cleaned/2003
# Moved 20021_m79.txt to data/cleaned/2002
# Moved 20031_m45.txt to data/cleaned/2003
# Moved 20011_m3.txt to data/cleaned/2001
# Moved 20021_m51.txt to data/cleaned/2002
# Moved 20021_m45.txt to data/cleaned/2002
# Moved 20111_m3.txt to data/cleaned/2011
# Moved 20031_m51.txt to data/cleaned/2003
# Moved 20222_m72.txt to data/cleaned/2022
# Moved 20001_m16.txt to data/cleaned/2000
# Moved 20222_m66.txt to data/cleaned/2022
# Moved 20031_m86.txt to data/cleaned/2003
# Moved 20021_m92.txt to data/cleaned/2002
# Moved 20021_m86.txt to data/cleaned/2002
# Moved 20031_m92.txt to data/cleaned/2003
# Moved 20021_m87.txt to data/cleaned/2002
# Moved 20031_m93.txt to data/cleaned/2003
# Moved 20031_m87.txt to data/cleaned/2003
# Moved 20021_m93.txt to data/cleaned/2002
# Moved 20001_m17.txt to data/cleaned/2000
# Moved 20222_m67.txt to data/cleaned/2022
# Moved 20222_m73.txt to data/cleaned/2022
# Moved 20021_m44.txt to data/cleaned/2002
# Moved 20031_m50.txt to data/cleaned/2003
# Moved 20111_m2.txt to data/cleaned/2011
# Moved 20031_m44.txt to data/cleaned/2003
# Moved 20021_m50.txt to data/cleaned/2002
# Moved 20011_m2.txt to data/cleaned/2001
# Moved 20021_m78.txt to data/cleaned/2002
# Moved 20031_m78.txt to data/cleaned/2003
# Moved 20191_m18.txt to data/cleaned/2019
# Moved 20151_m110.txt to data/cleaned/2015
# Moved 20061_m72.txt to data/cleaned/2006
# Moved 20181_m18.txt to data/cleaned/2018
# Moved 20151_m104.txt to data/cleaned/2015
# Moved 20061_m66.txt to data/cleaned/2006
# Moved 20191_m24.txt to data/cleaned/2019
# Moved 20181_m30.txt to data/cleaned/2018
# Moved 20072_m2.txt to data/cleaned/2007
# Moved 20181_m24.txt to data/cleaned/2018
# Moved 20191_m30.txt to data/cleaned/2019
# Moved 20091_m108.txt to data/cleaned/2009
# Moved 20001_m7.txt to data/cleaned/2000
# Moved 20101_m7.txt to data/cleaned/2010
# Moved 20051_m35.txt to data/cleaned/2005
# Moved 20041_m21.txt to data/cleaned/2004
# Moved 20061_m99.txt to data/cleaned/2006
# Moved 20041_m35.txt to data/cleaned/2004
# Moved 20051_m21.txt to data/cleaned/2005
# Moved 20111_m60.txt to data/cleaned/2011
# Moved 20101_m74.txt to data/cleaned/2010
# Moved 20101_m60.txt to data/cleaned/2010
# Moved 20111_m74.txt to data/cleaned/2011
# Moved 20101_m48.txt to data/cleaned/2010
# Moved 20042_m55.txt to data/cleaned/2004
# Moved 20042_m41.txt to data/cleaned/2004
# Moved 20111_m48.txt to data/cleaned/2011
# Moved 20241_m76.txt to data/cleaned/2024
# Moved 20072_m12.txt to data/cleaned/2007
# Moved 20181_m1.txt to data/cleaned/2018
# Moved 20081_m1.txt to data/cleaned/2008
# Moved 20231_m8.txt to data/cleaned/2023
# Moved 20241_m62.txt to data/cleaned/2024
# Moved 20131_m33.txt to data/cleaned/2013
# Moved 20121_m27.txt to data/cleaned/2012
# Moved 20121_m33.txt to data/cleaned/2012
# Moved 20131_m27.txt to data/cleaned/2013
# Moved 20081_m53.txt to data/cleaned/2008
# Moved 20141_m81.txt to data/cleaned/2014
# Moved 20211_m54.txt to data/cleaned/2021
# Moved 20201_m105.txt to data/cleaned/2020
# Moved 20091_m47.txt to data/cleaned/2009
# Moved 20151_m95.txt to data/cleaned/2015
# Moved 20171_m39.txt to data/cleaned/2017
# Moved 20201_m40.txt to data/cleaned/2020
# Moved 20151_m81.txt to data/cleaned/2015
# Moved 20201_m54.txt to data/cleaned/2020
# Moved 20091_m53.txt to data/cleaned/2009
# Moved 20141_m95.txt to data/cleaned/2014
# Moved 20161_m39.txt to data/cleaned/2016
# Moved 20201_m111.txt to data/cleaned/2020
# Moved 20211_m40.txt to data/cleaned/2021
# Moved 20081_m47.txt to data/cleaned/2008
# Moved 20211_m68.txt to data/cleaned/2021
# Moved 20161_m11.txt to data/cleaned/2016
# Moved 20201_m68.txt to data/cleaned/2020
# Moved 20171_m11.txt to data/cleaned/2017
# Moved 20091_m4.txt to data/cleaned/2009
# Moved 20211_m97.txt to data/cleaned/2021
# Moved 20141_m42.txt to data/cleaned/2014
# Moved 20081_m90.txt to data/cleaned/2008
# Moved 20201_m83.txt to data/cleaned/2020
# Moved 20151_m56.txt to data/cleaned/2015
# Moved 20091_m84.txt to data/cleaned/2009
# Moved 20091_m90.txt to data/cleaned/2009
# Moved 20191_m4.txt to data/cleaned/2019
# Moved 20201_m97.txt to data/cleaned/2020
# Moved 20151_m42.txt to data/cleaned/2015
# Moved 20081_m84.txt to data/cleaned/2008
# Moved 20211_m83.txt to data/cleaned/2021
# Moved 20141_m56.txt to data/cleaned/2014
# Moved 20012_m77.txt to data/cleaned/2001
# Moved 20012_m63.txt to data/cleaned/2001
# Moved 20231_m13.txt to data/cleaned/2023
# Moved 20131_m103.txt to data/cleaned/2013
# Moved 20151_m68.txt to data/cleaned/2015
# Moved 20012_m75.txt to data/cleaned/2001
# Moved 20131_m101.txt to data/cleaned/2013
# Moved 20231_m11.txt to data/cleaned/2023
# Moved 20141_m68.txt to data/cleaned/2014
# Moved 20012_m61.txt to data/cleaned/2001
# Moved 20091_m86.txt to data/cleaned/2009
# Moved 20012_m49.txt to data/cleaned/2001
# Moved 20151_m54.txt to data/cleaned/2015
# Moved 20201_m81.txt to data/cleaned/2020
# Moved 20081_m92.txt to data/cleaned/2008
# Moved 20141_m40.txt to data/cleaned/2014
# Moved 20231_m39.txt to data/cleaned/2023
# Moved 20211_m95.txt to data/cleaned/2021
# Moved 20091_m6.txt to data/cleaned/2009
# Moved 20141_m54.txt to data/cleaned/2014
# Moved 20211_m81.txt to data/cleaned/2021
# Moved 20081_m86.txt to data/cleaned/2008
# Moved 20151_m40.txt to data/cleaned/2015
# Moved 20201_m95.txt to data/cleaned/2020
# Moved 20191_m6.txt to data/cleaned/2019
# Moved 20091_m92.txt to data/cleaned/2009
# Moved 20091_m79.txt to data/cleaned/2009
# Moved 20161_m13.txt to data/cleaned/2016
# Moved 20081_m79.txt to data/cleaned/2008
# Moved 20171_m13.txt to data/cleaned/2017
# Moved 20201_m42.txt to data/cleaned/2020
# Moved 20151_m97.txt to data/cleaned/2015
# Moved 20091_m45.txt to data/cleaned/2009
# Moved 20201_m107.txt to data/cleaned/2020
# Moved 20211_m56.txt to data/cleaned/2021
# Moved 20141_m83.txt to data/cleaned/2014
# Moved 20081_m51.txt to data/cleaned/2008
# Moved 20081_m45.txt to data/cleaned/2008
# Moved 20211_m42.txt to data/cleaned/2021
# Moved 20201_m113.txt to data/cleaned/2020
# Moved 20141_m97.txt to data/cleaned/2014
# Moved 20091_m51.txt to data/cleaned/2009
# Moved 20201_m56.txt to data/cleaned/2020
# Moved 20151_m83.txt to data/cleaned/2015
# Moved 20101_m89.txt to data/cleaned/2010
# Moved 20121_m25.txt to data/cleaned/2012
# Moved 20151_m8.txt to data/cleaned/2015
# Moved 20131_m31.txt to data/cleaned/2013
# Moved 20241_m48.txt to data/cleaned/2024
# Moved 20051_m8.txt to data/cleaned/2005
# Moved 20072_m38.txt to data/cleaned/2007
# Moved 20111_m89.txt to data/cleaned/2011
# Moved 20131_m25.txt to data/cleaned/2013
# Moved 20121_m31.txt to data/cleaned/2012
# Moved 20121_m19.txt to data/cleaned/2012
# Moved 20072_m10.txt to data/cleaned/2007
# Moved 20181_m3.txt to data/cleaned/2018
# Moved 20241_m74.txt to data/cleaned/2024
# Moved 20241_m60.txt to data/cleaned/2024
# Moved 20131_m19.txt to data/cleaned/2013
# Moved 20081_m3.txt to data/cleaned/2008
# Moved 20042_m43.txt to data/cleaned/2004
# Moved 20101_m76.txt to data/cleaned/2010
# Moved 20111_m62.txt to data/cleaned/2011
# Moved 20111_m76.txt to data/cleaned/2011
# Moved 20101_m62.txt to data/cleaned/2010
# Moved 20041_m23.txt to data/cleaned/2004
# Moved 20051_m37.txt to data/cleaned/2005
# Moved 20051_m23.txt to data/cleaned/2005
# Moved 20041_m37.txt to data/cleaned/2004
# Moved 20001_m5.txt to data/cleaned/2000
# Moved 20101_m5.txt to data/cleaned/2010
# Moved 20181_m32.txt to data/cleaned/2018
# Moved 20191_m26.txt to data/cleaned/2019
# Moved 20191_m32.txt to data/cleaned/2019
# Moved 20181_m26.txt to data/cleaned/2018
# Moved 20061_m58.txt to data/cleaned/2006
# Moved 20061_m70.txt to data/cleaned/2006
# Moved 20151_m112.txt to data/cleaned/2015
# Moved 20061_m64.txt to data/cleaned/2006
# Moved 20151_m106.txt to data/cleaned/2015
# Moved 20031_m52.txt to data/cleaned/2003
# Moved 20021_m46.txt to data/cleaned/2002
# Moved 20021_m52.txt to data/cleaned/2002
# Moved 20031_m46.txt to data/cleaned/2003
# Moved 20222_m65.txt to data/cleaned/2022
# Moved 20001_m15.txt to data/cleaned/2000
# Moved 20222_m71.txt to data/cleaned/2022
# Moved 20222_m59.txt to data/cleaned/2022
# Moved 20031_m91.txt to data/cleaned/2003
# Moved 20021_m85.txt to data/cleaned/2002
# Moved 20001_m29.txt to data/cleaned/2000
# Moved 20021_m91.txt to data/cleaned/2002
# Moved 20031_m85.txt to data/cleaned/2003
# Moved 20021_m90.txt to data/cleaned/2002
# Moved 20031_m84.txt to data/cleaned/2003
# Moved 20031_m90.txt to data/cleaned/2003
# Moved 20222_m58.txt to data/cleaned/2022
# Moved 20001_m28.txt to data/cleaned/2000
# Moved 20021_m84.txt to data/cleaned/2002
# Moved 20222_m70.txt to data/cleaned/2022
# Moved 20222_m64.txt to data/cleaned/2022
# Moved 20001_m14.txt to data/cleaned/2000
# Moved 20021_m53.txt to data/cleaned/2002
# Moved 20011_m1.txt to data/cleaned/2001
# Moved 20031_m47.txt to data/cleaned/2003
# Moved 20031_m53.txt to data/cleaned/2003
# Moved 20111_m1.txt to data/cleaned/2011
# Moved 20021_m47.txt to data/cleaned/2002
# Moved 20151_m107.txt to data/cleaned/2015
# Moved 20061_m65.txt to data/cleaned/2006
# Moved 20061_m71.txt to data/cleaned/2006
# Moved 20191_m33.txt to data/cleaned/2019
# Moved 20072_m1.txt to data/cleaned/2007
# Moved 20061_m59.txt to data/cleaned/2006
# Moved 20181_m27.txt to data/cleaned/2018
# Moved 20181_m33.txt to data/cleaned/2018
# Moved 20191_m27.txt to data/cleaned/2019
# Moved 20101_m4.txt to data/cleaned/2010
# Moved 20001_m4.txt to data/cleaned/2000
# Moved 20051_m22.txt to data/cleaned/2005
# Moved 20041_m36.txt to data/cleaned/2004
# Moved 20041_m22.txt to data/cleaned/2004
# Moved 20051_m36.txt to data/cleaned/2005
# Moved 20111_m77.txt to data/cleaned/2011
# Moved 20101_m63.txt to data/cleaned/2010
# Moved 20101_m77.txt to data/cleaned/2010
# Moved 20111_m63.txt to data/cleaned/2011
# Moved 20042_m42.txt to data/cleaned/2004
# Moved 20101_m108.txt to data/cleaned/2010
# Moved 20241_m61.txt to data/cleaned/2024
# Moved 20131_m18.txt to data/cleaned/2013
# Moved 20081_m2.txt to data/cleaned/2008
# Moved 20121_m18.txt to data/cleaned/2012
# Moved 20241_m75.txt to data/cleaned/2024
# Moved 20072_m11.txt to data/cleaned/2007
# Moved 20181_m2.txt to data/cleaned/2018
# Moved 20131_m24.txt to data/cleaned/2013
# Moved 20111_m88.txt to data/cleaned/2011
# Moved 20051_m9.txt to data/cleaned/2005
# Moved 20072_m39.txt to data/cleaned/2007
# Moved 20121_m30.txt to data/cleaned/2012
# Moved 20151_m9.txt to data/cleaned/2015
# Moved 20121_m24.txt to data/cleaned/2012
# Moved 20101_m88.txt to data/cleaned/2010
# Moved 20131_m30.txt to data/cleaned/2013
# Moved 20241_m49.txt to data/cleaned/2024
# Moved 20141_m96.txt to data/cleaned/2014
# Moved 20211_m43.txt to data/cleaned/2021
# Moved 20201_m112.txt to data/cleaned/2020
# Moved 20081_m44.txt to data/cleaned/2008
# Moved 20151_m82.txt to data/cleaned/2015
# Moved 20201_m57.txt to data/cleaned/2020
# Moved 20091_m50.txt to data/cleaned/2009
# Moved 20091_m44.txt to data/cleaned/2009
# Moved 20151_m96.txt to data/cleaned/2015
# Moved 20201_m43.txt to data/cleaned/2020
# Moved 20081_m50.txt to data/cleaned/2008
# Moved 20141_m82.txt to data/cleaned/2014
# Moved 20201_m106.txt to data/cleaned/2020
# Moved 20211_m57.txt to data/cleaned/2021
# Moved 20081_m78.txt to data/cleaned/2008
# Moved 20171_m12.txt to data/cleaned/2017
# Moved 20091_m78.txt to data/cleaned/2009
# Moved 20161_m12.txt to data/cleaned/2016
# Moved 20081_m87.txt to data/cleaned/2008
# Moved 20211_m80.txt to data/cleaned/2021
# Moved 20141_m55.txt to data/cleaned/2014
# Moved 20091_m93.txt to data/cleaned/2009
# Moved 20201_m94.txt to data/cleaned/2020
# Moved 20191_m7.txt to data/cleaned/2019
# Moved 20151_m41.txt to data/cleaned/2015
# Moved 20201_m80.txt to data/cleaned/2020
# Moved 20151_m55.txt to data/cleaned/2015
# Moved 20012_m48.txt to data/cleaned/2001
# Moved 20091_m87.txt to data/cleaned/2009
# Moved 20211_m94.txt to data/cleaned/2021
# Moved 20091_m7.txt to data/cleaned/2009
# Moved 20141_m41.txt to data/cleaned/2014
# Moved 20231_m38.txt to data/cleaned/2023
# Moved 20081_m93.txt to data/cleaned/2008
# Moved 20231_m10.txt to data/cleaned/2023
# Moved 20141_m69.txt to data/cleaned/2014
# Moved 20131_m100.txt to data/cleaned/2013
# Moved 20012_m60.txt to data/cleaned/2001
# Moved 20012_m74.txt to data/cleaned/2001
# Moved 20151_m69.txt to data/cleaned/2015
# Moved 20081_m97.txt to data/cleaned/2008
# Moved 20141_m45.txt to data/cleaned/2014
# Moved 20091_m3.txt to data/cleaned/2009
# Moved 20211_m90.txt to data/cleaned/2021
# Moved 20091_m83.txt to data/cleaned/2009
# Moved 20151_m51.txt to data/cleaned/2015
# Moved 20201_m84.txt to data/cleaned/2020
# Moved 20151_m45.txt to data/cleaned/2015
# Moved 20191_m3.txt to data/cleaned/2019
# Moved 20201_m90.txt to data/cleaned/2020
# Moved 20091_m97.txt to data/cleaned/2009
# Moved 20012_m58.txt to data/cleaned/2001
# Moved 20141_m51.txt to data/cleaned/2014
# Moved 20231_m28.txt to data/cleaned/2023
# Moved 20211_m84.txt to data/cleaned/2021
# Moved 20081_m83.txt to data/cleaned/2008
# Moved 20141_m79.txt to data/cleaned/2014
# Moved 20041_m8.txt to data/cleaned/2004
# Moved 20012_m70.txt to data/cleaned/2001
# Moved 20012_m64.txt to data/cleaned/2001
# Moved 20151_m79.txt to data/cleaned/2015
# Moved 20131_m104.txt to data/cleaned/2013
# Moved 20231_m14.txt to data/cleaned/2023
# Moved 20141_m8.txt to data/cleaned/2014
# Moved 20211_m53.txt to data/cleaned/2021
# Moved 20201_m102.txt to data/cleaned/2020
# Moved 20141_m86.txt to data/cleaned/2014
# Moved 20081_m54.txt to data/cleaned/2008
# Moved 20201_m47.txt to data/cleaned/2020
# Moved 20151_m92.txt to data/cleaned/2015
# Moved 20091_m40.txt to data/cleaned/2009
# Moved 20091_m54.txt to data/cleaned/2009
# Moved 20201_m53.txt to data/cleaned/2020
# Moved 20151_m86.txt to data/cleaned/2015
# Moved 20081_m40.txt to data/cleaned/2008
# Moved 20201_m116.txt to data/cleaned/2020
# Moved 20211_m47.txt to data/cleaned/2021
# Moved 20141_m92.txt to data/cleaned/2014
# Moved 20081_m68.txt to data/cleaned/2008
# Moved 20161_m16.txt to data/cleaned/2016
# Moved 20171_m16.txt to data/cleaned/2017
# Moved 20091_m68.txt to data/cleaned/2009
# Moved 20072_m15.txt to data/cleaned/2007
# Moved 20181_m6.txt to data/cleaned/2018
# Moved 20241_m71.txt to data/cleaned/2024
# Moved 20081_m6.txt to data/cleaned/2008
# Moved 20241_m65.txt to data/cleaned/2024
# Moved 20111_m98.txt to data/cleaned/2011
# Moved 20131_m34.txt to data/cleaned/2013
# Moved 20072_m29.txt to data/cleaned/2007
# Moved 20121_m20.txt to data/cleaned/2012
# Moved 20101_m98.txt to data/cleaned/2010
# Moved 20121_m34.txt to data/cleaned/2012
# Moved 20131_m20.txt to data/cleaned/2013
# Moved 20241_m59.txt to data/cleaned/2024
# Moved 20111_m67.txt to data/cleaned/2011
# Moved 20101_m73.txt to data/cleaned/2010
# Moved 20101_m67.txt to data/cleaned/2010
# Moved 20111_m73.txt to data/cleaned/2011
# Moved 20042_m52.txt to data/cleaned/2004
# Moved 20042_m46.txt to data/cleaned/2004
# Moved 20051_m32.txt to data/cleaned/2005
# Moved 20041_m26.txt to data/cleaned/2004
# Moved 20041_m32.txt to data/cleaned/2004
# Moved 20051_m26.txt to data/cleaned/2005
# Moved 20061_m75.txt to data/cleaned/2006
# Moved 20061_m61.txt to data/cleaned/2006
# Moved 20151_m103.txt to data/cleaned/2015
# Moved 20191_m23.txt to data/cleaned/2019
# Moved 20061_m49.txt to data/cleaned/2006
# Moved 20181_m37.txt to data/cleaned/2018
# Moved 20181_m23.txt to data/cleaned/2018
# Moved 20072_m5.txt to data/cleaned/2007
# Moved 20191_m37.txt to data/cleaned/2019
# Moved 20021_m43.txt to data/cleaned/2002
# Moved 20111_m5.txt to data/cleaned/2011
# Moved 20031_m57.txt to data/cleaned/2003
# Moved 20031_m43.txt to data/cleaned/2003
# Moved 20011_m5.txt to data/cleaned/2001
# Moved 20021_m57.txt to data/cleaned/2002
# Moved 20021_m80.txt to data/cleaned/2002
# Moved 20031_m94.txt to data/cleaned/2003
# Moved 20031_m80.txt to data/cleaned/2003
# Moved 20222_m48.txt to data/cleaned/2022
# Moved 20021_m94.txt to data/cleaned/2002
# Moved 20001_m38.txt to data/cleaned/2000
# Moved 20001_m10.txt to data/cleaned/2000
# Moved 20222_m60.txt to data/cleaned/2022
# Moved 20011_m10.txt to data/cleaned/2001
# Moved 20011_m11.txt to data/cleaned/2001
# Moved 20001_m11.txt to data/cleaned/2000
# Moved 20222_m61.txt to data/cleaned/2022
# Moved 20222_m49.txt to data/cleaned/2022
# Moved 20031_m81.txt to data/cleaned/2003
# Moved 20001_m39.txt to data/cleaned/2000
# Moved 20021_m95.txt to data/cleaned/2002
# Moved 20021_m81.txt to data/cleaned/2002
# Moved 20031_m95.txt to data/cleaned/2003
# Moved 20031_m42.txt to data/cleaned/2003
# Moved 20021_m56.txt to data/cleaned/2002
# Moved 20011_m4.txt to data/cleaned/2001
# Moved 20021_m42.txt to data/cleaned/2002
# Moved 20031_m56.txt to data/cleaned/2003
# Moved 20111_m4.txt to data/cleaned/2011
# Moved 20072_m4.txt to data/cleaned/2007
# Moved 20181_m22.txt to data/cleaned/2018
# Moved 20191_m36.txt to data/cleaned/2019
# Moved 20191_m22.txt to data/cleaned/2019
# Moved 20181_m36.txt to data/cleaned/2018
# Moved 20061_m48.txt to data/cleaned/2006
# Moved 20151_m102.txt to data/cleaned/2015
# Moved 20061_m60.txt to data/cleaned/2006
# Moved 20061_m74.txt to data/cleaned/2006
# Moved 20041_m33.txt to data/cleaned/2004
# Moved 20051_m27.txt to data/cleaned/2005
# Moved 20051_m33.txt to data/cleaned/2005
# Moved 20041_m27.txt to data/cleaned/2004
# Moved 20101_m1.txt to data/cleaned/2010
# Moved 20001_m1.txt to data/cleaned/2000
# Moved 20042_m47.txt to data/cleaned/2004
# Moved 20042_m53.txt to data/cleaned/2004
# Moved 20101_m66.txt to data/cleaned/2010
# Moved 20111_m72.txt to data/cleaned/2011
# Moved 20111_m66.txt to data/cleaned/2011
# Moved 20101_m72.txt to data/cleaned/2010
# Moved 20121_m35.txt to data/cleaned/2012
# Moved 20101_m99.txt to data/cleaned/2010
# Moved 20131_m21.txt to data/cleaned/2013
# Moved 20241_m58.txt to data/cleaned/2024
# Moved 20072_m28.txt to data/cleaned/2007
# Moved 20131_m35.txt to data/cleaned/2013
# Moved 20111_m99.txt to data/cleaned/2011
# Moved 20121_m21.txt to data/cleaned/2012
# Moved 20081_m7.txt to data/cleaned/2008
# Moved 20241_m64.txt to data/cleaned/2024
# Moved 20241_m70.txt to data/cleaned/2024
# Moved 20072_m14.txt to data/cleaned/2007
# Moved 20181_m7.txt to data/cleaned/2018
# Moved 20091_m69.txt to data/cleaned/2009
# Moved 20171_m17.txt to data/cleaned/2017
# Moved 20161_m17.txt to data/cleaned/2016
# Moved 20081_m69.txt to data/cleaned/2008
# Moved 20151_m87.txt to data/cleaned/2015
# Moved 20201_m52.txt to data/cleaned/2020
# Moved 20091_m55.txt to data/cleaned/2009
# Moved 20141_m93.txt to data/cleaned/2014
# Moved 20201_m117.txt to data/cleaned/2020
# Moved 20211_m46.txt to data/cleaned/2021
# ...
# Moved 20031_m11.txt to data/cleaned/2003
# Moved 20031_m39.txt to data/cleaned/2003
# Moved 20001_m81.txt to data/cleaned/2000
# Moved 20021_m39.txt to data/cleaned/2002
# Moved 20001_m95.txt to data/cleaned/2000
# Moved 20181_m59.txt to data/cleaned/2018
# Moved 20061_m27.txt to data/cleaned/2006
# Moved 20061_m3.txt to data/cleaned/2006
# Moved 20191_m59.txt to data/cleaned/2019
# Moved 20161_m3.txt to data/cleaned/2016
# Moved 20061_m33.txt to data/cleaned/2006
# Moved 20211_m133.txt to data/cleaned/2021
# Moved 20201_m1.txt to data/cleaned/2020
# Moved 20181_m65.txt to data/cleaned/2018
# Moved 20191_m71.txt to data/cleaned/2019
# Moved 20191_m65.txt to data/cleaned/2019
# Moved 20181_m71.txt to data/cleaned/2018
# Moved 20211_m127.txt to data/cleaned/2021
# Moved 20051_m48.txt to data/cleaned/2005
# Moved 20051_m60.txt to data/cleaned/2005
# Moved 20051_m74.txt to data/cleaned/2005
# Moved 20012_m6.txt to data/cleaned/2001
# Moved 20121_m109.txt to data/cleaned/2012
# Moved 20101_m21.txt to data/cleaned/2010
# Moved 20111_m35.txt to data/cleaned/2011
# Moved 20131_m99.txt to data/cleaned/2013
# Moved 20072_m84.txt to data/cleaned/2007
# Moved 20111_m21.txt to data/cleaned/2011
# Moved 20042_m28.txt to data/cleaned/2004
# Moved 20101_m35.txt to data/cleaned/2010
# Moved 20121_m99.txt to data/cleaned/2012
# Moved 20171_m106.txt to data/cleaned/2017
# Moved 20042_m14.txt to data/cleaned/2004
# Moved 20072_m47.txt to data/cleaned/2007
# Moved 20241_m23.txt to data/cleaned/2024
# Moved 20241_m37.txt to data/cleaned/2024
# Moved 20072_m53.txt to data/cleaned/2007
# Moved 20121_m72.txt to data/cleaned/2012
# Moved 20131_m66.txt to data/cleaned/2013
# Moved 20222_m9.txt to data/cleaned/2022
# Moved 20131_m72.txt to data/cleaned/2013
# Moved 20121_m66.txt to data/cleaned/2012
# Moved 20241_m9.txt to data/cleaned/2024
# Moved 20201_m15.txt to data/cleaned/2020
# Moved 20091_m12.txt to data/cleaned/2009
# Moved 20161_m78.txt to data/cleaned/2016
# Moved 20081_m12.txt to data/cleaned/2008
# Moved 20211_m15.txt to data/cleaned/2021
# Moved 20171_m78.txt to data/cleaned/2017
# Moved 20051_m101.txt to data/cleaned/2005
# Moved 20171_m50.txt to data/cleaned/2017
# Moved 20201_m29.txt to data/cleaned/2020
# Moved 20231_m91.txt to data/cleaned/2023
# Moved 20161_m44.txt to data/cleaned/2016
# Moved 20231_m85.txt to data/cleaned/2023
# Moved 20161_m50.txt to data/cleaned/2016
# Moved 20211_m29.txt to data/cleaned/2021
# Moved 20171_m44.txt to data/cleaned/2017
# Moved 20081_m102.txt to data/cleaned/2008
# Moved 20191_m125.txt to data/cleaned/2019
# Moved 20141_m17.txt to data/cleaned/2014
# Moved 20191_m131.txt to data/cleaned/2019
# Moved 20151_m17.txt to data/cleaned/2015
# Moved 20171_m93.txt to data/cleaned/2017
# Moved 20012_m22.txt to data/cleaned/2001
# Moved 20161_m87.txt to data/cleaned/2016
# Moved 20191_m119.txt to data/cleaned/2019
# Moved 20182_m5.txt to data/cleaned/2018
# Moved 20231_m52.txt to data/cleaned/2023
# Moved 20161_m93.txt to data/cleaned/2016
# Moved 20231_m46.txt to data/cleaned/2023
# Moved 20012_m36.txt to data/cleaned/2001
# Moved 20171_m87.txt to data/cleaned/2017
# Moved 20151_m13.txt to data/cleaned/2015
# Moved 20191_m135.txt to data/cleaned/2019
# Moved 20141_m13.txt to data/cleaned/2014
# Moved 20191_m121.txt to data/cleaned/2019
# Moved 20081_m106.txt to data/cleaned/2008
# Moved 20171_m83.txt to data/cleaned/2017
# Moved 20012_m32.txt to data/cleaned/2001
# Moved 20231_m42.txt to data/cleaned/2023
# Moved 20161_m97.txt to data/cleaned/2016
# Moved 20191_m109.txt to data/cleaned/2019
# Moved 20231_m56.txt to data/cleaned/2023
# Moved 20182_m1.txt to data/cleaned/2018
# Moved 20161_m83.txt to data/cleaned/2016
# Moved 20012_m26.txt to data/cleaned/2001
# Moved 20171_m97.txt to data/cleaned/2017
# Moved 20211_m11.txt to data/cleaned/2021
# Moved 20161_m68.txt to data/cleaned/2016
# Moved 20081_m16.txt to data/cleaned/2008
# Moved 20091_m16.txt to data/cleaned/2009
# Moved 20201_m11.txt to data/cleaned/2020
# Moved 20171_m68.txt to data/cleaned/2017
# Moved 20171_m40.txt to data/cleaned/2017
# Moved 20201_m39.txt to data/cleaned/2020
# Moved 20161_m54.txt to data/cleaned/2016
# Moved 20231_m81.txt to data/cleaned/2023
# Moved 20161_m40.txt to data/cleaned/2016
# Moved 20211_m39.txt to data/cleaned/2021
# Moved 20231_m95.txt to data/cleaned/2023
# Moved 20171_m54.txt to data/cleaned/2017
# Moved 20072_m57.txt to data/cleaned/2007
# Moved 20241_m33.txt to data/cleaned/2024
# Moved 20241_m27.txt to data/cleaned/2024
# Moved 20072_m43.txt to data/cleaned/2007
# Moved 20121_m62.txt to data/cleaned/2012
# Moved 20131_m76.txt to data/cleaned/2013
# Moved 20131_m62.txt to data/cleaned/2013
# Moved 20121_m76.txt to data/cleaned/2012
# Moved 20101_m31.txt to data/cleaned/2010
# Moved 20131_m89.txt to data/cleaned/2013
# Moved 20111_m25.txt to data/cleaned/2011
# Moved 20072_m80.txt to data/cleaned/2007
# Moved 20111_m31.txt to data/cleaned/2011
# Moved 20042_m38.txt to data/cleaned/2004
# Moved 20121_m89.txt to data/cleaned/2012
# Moved 20101_m25.txt to data/cleaned/2010
# Moved 20042_m10.txt to data/cleaned/2004
# Moved 20171_m102.txt to data/cleaned/2017
# Moved 20111_m19.txt to data/cleaned/2011
# Moved 20101_m19.txt to data/cleaned/2010
# Moved 20051_m58.txt to data/cleaned/2005
# Moved 20031_m102.txt to data/cleaned/2003
# Moved 20012_m2.txt to data/cleaned/2001
# Moved 20051_m70.txt to data/cleaned/2005
# Moved 20051_m64.txt to data/cleaned/2005
# Moved 20181_m49.txt to data/cleaned/2018
# Moved 20061_m37.txt to data/cleaned/2006
# Moved 20161_m7.txt to data/cleaned/2016
# Moved 20061_m7.txt to data/cleaned/2006
# Moved 20191_m49.txt to data/cleaned/2019
# Moved 20061_m23.txt to data/cleaned/2006
# Moved 20211_m123.txt to data/cleaned/2021
# Moved 20181_m75.txt to data/cleaned/2018
# Moved 20191_m61.txt to data/cleaned/2019
# Moved 20191_m75.txt to data/cleaned/2019
# Moved 20181_m61.txt to data/cleaned/2018
# Moved 20201_m5.txt to data/cleaned/2020
# Moved 20031_m15.txt to data/cleaned/2003
# Moved 20021_m15.txt to data/cleaned/2002
# Moved 20031_m29.txt to data/cleaned/2003
# Moved 20001_m91.txt to data/cleaned/2000
# Moved 20001_m85.txt to data/cleaned/2000
# Moved 20021_m29.txt to data/cleaned/2002
# Moved 20071_m2.txt to data/cleaned/2007
# Moved 20171_m2.txt to data/cleaned/2017
# Moved 20222_m22.txt to data/cleaned/2022
# Moved 20001_m52.txt to data/cleaned/2000
# Moved 20001_m46.txt to data/cleaned/2000
# Moved 20222_m36.txt to data/cleaned/2022
# Moved 20001_m47.txt to data/cleaned/2000
# Moved 20222_m37.txt to data/cleaned/2022
# Moved 20222_m23.txt to data/cleaned/2022
# Moved 20001_m53.txt to data/cleaned/2000
# Moved 20211_m1.txt to data/cleaned/2021
# Moved 20171_m3.txt to data/cleaned/2017
# Moved 20071_m3.txt to data/cleaned/2007
# Moved 20021_m28.txt to data/cleaned/2002
# Moved 20001_m84.txt to data/cleaned/2000
# Moved 20031_m28.txt to data/cleaned/2003
# Moved 20001_m90.txt to data/cleaned/2000
# Moved 20021_m14.txt to data/cleaned/2002
# Moved 20031_m14.txt to data/cleaned/2003
# Moved 20191_m74.txt to data/cleaned/2019
# Moved 20201_m4.txt to data/cleaned/2020
# Moved 20181_m60.txt to data/cleaned/2018
# Moved 20181_m74.txt to data/cleaned/2018
# Moved 20211_m122.txt to data/cleaned/2021
# Moved 20191_m60.txt to data/cleaned/2019
# Moved 20191_m48.txt to data/cleaned/2019
# Moved 20061_m6.txt to data/cleaned/2006
# Moved 20061_m22.txt to data/cleaned/2006
# Moved 20061_m36.txt to data/cleaned/2006
# Moved 20161_m6.txt to data/cleaned/2016
# Moved 20181_m48.txt to data/cleaned/2018
# Moved 20051_m65.txt to data/cleaned/2005
# Moved 20051_m71.txt to data/cleaned/2005
# Moved 20012_m3.txt to data/cleaned/2001
# Moved 20031_m103.txt to data/cleaned/2003
# Moved 20051_m59.txt to data/cleaned/2005
# Moved 20101_m18.txt to data/cleaned/2010
# Moved 20042_m11.txt to data/cleaned/2004
# Moved 20111_m18.txt to data/cleaned/2011
# Moved 20171_m103.txt to data/cleaned/2017
# Moved 20111_m30.txt to data/cleaned/2011
# Moved 20072_m81.txt to data/cleaned/2007
# Moved 20101_m24.txt to data/cleaned/2010
# Moved 20121_m88.txt to data/cleaned/2012
# Moved 20042_m39.txt to data/cleaned/2004
# Moved 20101_m30.txt to data/cleaned/2010
# Moved 20111_m24.txt to data/cleaned/2011
# Moved 20131_m88.txt to data/cleaned/2013
# Moved 20131_m63.txt to data/cleaned/2013
# Moved 20121_m77.txt to data/cleaned/2012
# Moved 20121_m63.txt to data/cleaned/2012
# Moved 20131_m77.txt to data/cleaned/2013
# Moved 20072_m42.txt to data/cleaned/2007
# Moved 20241_m26.txt to data/cleaned/2024
# Moved 20241_m32.txt to data/cleaned/2024
# Moved 20072_m56.txt to data/cleaned/2007
# Moved 20231_m94.txt to data/cleaned/2023
# Moved 20161_m41.txt to data/cleaned/2016
# Moved 20211_m38.txt to data/cleaned/2021
# Moved 20171_m55.txt to data/cleaned/2017
# Moved 20171_m41.txt to data/cleaned/2017
# Moved 20201_m38.txt to data/cleaned/2020
# Moved 20231_m80.txt to data/cleaned/2023
# Moved 20161_m55.txt to data/cleaned/2016
# Moved 20201_m10.txt to data/cleaned/2020
# Moved 20171_m69.txt to data/cleaned/2017
# Moved 20091_m17.txt to data/cleaned/2009
# Moved 20081_m17.txt to data/cleaned/2008
# Moved 20211_m10.txt to data/cleaned/2021
# Moved 20161_m69.txt to data/cleaned/2016
# Moved 20161_m82.txt to data/cleaned/2016
# Moved 20231_m57.txt to data/cleaned/2023
# Moved 20171_m96.txt to data/cleaned/2017
# Moved 20012_m27.txt to data/cleaned/2001
# Moved 20012_m33.txt to data/cleaned/2001
# Moved 20171_m82.txt to data/cleaned/2017
# Moved 20161_m96.txt to data/cleaned/2016
# Moved 20191_m108.txt to data/cleaned/2019
# Moved 20231_m43.txt to data/cleaned/2023
# Moved 20191_m120.txt to data/cleaned/2019
# Moved 20141_m12.txt to data/cleaned/2014
# Moved 20151_m12.txt to data/cleaned/2015
# Moved 20191_m134.txt to data/cleaned/2019
# Moved 20081_m105.txt to data/cleaned/2008
# Moved 20012_m19.txt to data/cleaned/2001
# Moved 20231_m69.txt to data/cleaned/2023
# Moved 20141_m10.txt to data/cleaned/2014
# Moved 20191_m122.txt to data/cleaned/2019
# Moved 20191_m136.txt to data/cleaned/2019
# Moved 20151_m10.txt to data/cleaned/2015
# Moved 20012_m25.txt to data/cleaned/2001
# Moved 20151_m38.txt to data/cleaned/2015
# Moved 20171_m94.txt to data/cleaned/2017
# Moved 20231_m55.txt to data/cleaned/2023
# Moved 20161_m80.txt to data/cleaned/2016
# Moved 20182_m2.txt to data/cleaned/2018
# Moved 20141_m38.txt to data/cleaned/2014
# Moved 20231_m41.txt to data/cleaned/2023
# Moved 20161_m94.txt to data/cleaned/2016
# Moved 20171_m80.txt to data/cleaned/2017
# Moved 20012_m31.txt to data/cleaned/2001
# Moved 20091_m15.txt to data/cleaned/2009
# Moved 20201_m12.txt to data/cleaned/2020
# Moved 20211_m12.txt to data/cleaned/2021
# Moved 20081_m15.txt to data/cleaned/2008
# Moved 20171_m57.txt to data/cleaned/2017
# Moved 20091_m29.txt to data/cleaned/2009
# Moved 20161_m43.txt to data/cleaned/2016
# Moved 20231_m96.txt to data/cleaned/2023
# Moved 20081_m29.txt to data/cleaned/2008
# Moved 20161_m57.txt to data/cleaned/2016
# Moved 20231_m82.txt to data/cleaned/2023
# Moved 20171_m43.txt to data/cleaned/2017
# Moved 20121_m49.txt to data/cleaned/2012
# Moved 20241_m24.txt to data/cleaned/2024
# Moved 20072_m40.txt to data/cleaned/2007
# Moved 20072_m54.txt to data/cleaned/2007
# Moved 20131_m49.txt to data/cleaned/2013
# Moved 20241_m30.txt to data/cleaned/2024
# Moved 20121_m75.txt to data/cleaned/2012
# Moved 20241_m18.txt to data/cleaned/2024
# Moved 20131_m61.txt to data/cleaned/2013
# Moved 20131_m75.txt to data/cleaned/2013
# Moved 20072_m68.txt to data/cleaned/2007
# Moved 20121_m61.txt to data/cleaned/2012
# Moved 20101_m26.txt to data/cleaned/2010
# Moved 20072_m83.txt to data/cleaned/2007
# Moved 20111_m32.txt to data/cleaned/2011
# Moved 20111_m26.txt to data/cleaned/2011
# Moved 20101_m32.txt to data/cleaned/2010
# Moved 20131_m9.txt to data/cleaned/2013
# Moved 20171_m101.txt to data/cleaned/2017
# Moved 20042_m13.txt to data/cleaned/2004
# Moved 20031_m9.txt to data/cleaned/2003
# Moved 20191_m89.txt to data/cleaned/2019
# Moved 20031_m101.txt to data/cleaned/2003
# Moved 20181_m89.txt to data/cleaned/2018
# Moved 20051_m67.txt to data/cleaned/2005
# Moved 20012_m1.txt to data/cleaned/2001
# Moved 20051_m73.txt to data/cleaned/2005
# Moved 20061_m20.txt to data/cleaned/2006
# Moved 20211_m108.txt to data/cleaned/2021
# Moved 20061_m4.txt to data/cleaned/2006
# Moved 20051_m98.txt to data/cleaned/2005
# Moved 20161_m4.txt to data/cleaned/2016
# Moved 20061_m34.txt to data/cleaned/2006
# Moved 20181_m62.txt to data/cleaned/2018
# Moved 20201_m6.txt to data/cleaned/2020
# Moved 20211_m134.txt to data/cleaned/2021
# Moved 20191_m76.txt to data/cleaned/2019
# Moved 20191_m62.txt to data/cleaned/2019
# Moved 20211_m120.txt to data/cleaned/2021
# Moved 20181_m76.txt to data/cleaned/2018
# Moved 20021_m16.txt to data/cleaned/2002
# Moved 20031_m16.txt to data/cleaned/2003
# Moved 20001_m86.txt to data/cleaned/2000
# Moved 20001_m92.txt to data/cleaned/2000
# Moved 20001_m79.txt to data/cleaned/2000
# Moved 20171_m1.txt to data/cleaned/2017
# Moved 20071_m1.txt to data/cleaned/2007
# Moved 20222_m35.txt to data/cleaned/2022
# Moved 20001_m45.txt to data/cleaned/2000
# Moved 20211_m3.txt to data/cleaned/2021
# Moved 20001_m51.txt to data/cleaned/2000
# Moved 20222_m21.txt to data/cleaned/2022
# Moved 20001_m50.txt to data/cleaned/2000
# Moved 20211_m2.txt to data/cleaned/2021
# Moved 20222_m20.txt to data/cleaned/2022
# Moved 20222_m34.txt to data/cleaned/2022
# Moved 20001_m44.txt to data/cleaned/2000
# Moved 20001_m78.txt to data/cleaned/2000
# Moved 20001_m93.txt to data/cleaned/2000
# Moved 20001_m87.txt to data/cleaned/2000
# Moved 20031_m17.txt to data/cleaned/2003
# Moved 20021_m17.txt to data/cleaned/2002
# Moved 20191_m63.txt to data/cleaned/2019
# Moved 20181_m77.txt to data/cleaned/2018
# Moved 20211_m121.txt to data/cleaned/2021
# Moved 20211_m135.txt to data/cleaned/2021
# Moved 20201_m7.txt to data/cleaned/2020
# Moved 20181_m63.txt to data/cleaned/2018
# Moved 20191_m77.txt to data/cleaned/2019
# Moved 20161_m5.txt to data/cleaned/2016
# Moved 20061_m35.txt to data/cleaned/2006
# Moved 20211_m109.txt to data/cleaned/2021
# Moved 20061_m21.txt to data/cleaned/2006
# Moved 20051_m99.txt to data/cleaned/2005
# Moved 20061_m5.txt to data/cleaned/2006
# Moved 20051_m72.txt to data/cleaned/2005
# Moved 20051_m66.txt to data/cleaned/2005
# Moved 20181_m88.txt to data/cleaned/2018
# Moved 20031_m100.txt to data/cleaned/2003
# Moved 20191_m88.txt to data/cleaned/2019
# Moved 20171_m100.txt to data/cleaned/2017
# Moved 20031_m8.txt to data/cleaned/2003
# Moved 20042_m12.txt to data/cleaned/2004
# Moved 20131_m8.txt to data/cleaned/2013
# Moved 20111_m27.txt to data/cleaned/2011
# Moved 20101_m33.txt to data/cleaned/2010
# Moved 20101_m27.txt to data/cleaned/2010
# Moved 20111_m33.txt to data/cleaned/2011
# Moved 20072_m82.txt to data/cleaned/2007
# Moved 20072_m69.txt to data/cleaned/2007
# Moved 20131_m74.txt to data/cleaned/2013
# Moved 20121_m60.txt to data/cleaned/2012
# Moved 20121_m74.txt to data/cleaned/2012
# Moved 20241_m19.txt to data/cleaned/2024
# Moved 20131_m60.txt to data/cleaned/2013
# Moved 20131_m48.txt to data/cleaned/2013
# Moved 20241_m31.txt to data/cleaned/2024
# Moved 20072_m55.txt to data/cleaned/2007
# Moved 20121_m48.txt to data/cleaned/2012
# Moved 20072_m41.txt to data/cleaned/2007
# Moved 20241_m25.txt to data/cleaned/2024
# Moved 20231_m83.txt to data/cleaned/2023
# Moved 20161_m56.txt to data/cleaned/2016
# Moved 20081_m28.txt to data/cleaned/2008
# Moved 20171_m42.txt to data/cleaned/2017
# Moved 20091_m28.txt to data/cleaned/2009
# Moved 20171_m56.txt to data/cleaned/2017
# Moved 20231_m97.txt to data/cleaned/2023
# Moved 20161_m42.txt to data/cleaned/2016
# Moved 20081_m14.txt to data/cleaned/2008
# Moved 20211_m13.txt to data/cleaned/2021
# Moved 20201_m13.txt to data/cleaned/2020
# Moved 20091_m14.txt to data/cleaned/2009
# Moved 20161_m95.txt to data/cleaned/2016
# Moved 20141_m39.txt to data/cleaned/2014
# Moved 20231_m40.txt to data/cleaned/2023
# Moved 20012_m30.txt to data/cleaned/2001
# Moved 20171_m81.txt to data/cleaned/2017
# Moved 20171_m95.txt to data/cleaned/2017
# Moved 20151_m39.txt to data/cleaned/2015
# Moved 20012_m24.txt to data/cleaned/2001
# Moved 20182_m3.txt to data/cleaned/2018
# Moved 20161_m81.txt to data/cleaned/2016
# Moved 20231_m54.txt to data/cleaned/2023
# Moved 20191_m137.txt to data/cleaned/2019
# Moved 20151_m11.txt to data/cleaned/2015
# Moved 20012_m18.txt to data/cleaned/2001
# Moved 20081_m104.txt to data/cleaned/2008
# Moved 20191_m123.txt to data/cleaned/2019
# Moved 20231_m68.txt to data/cleaned/2023
# Moved 20141_m11.txt to data/cleaned/2014
#
# ✅ All files sorted by year!
